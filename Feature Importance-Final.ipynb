# %%
# Importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %%
#Uploading training data into the dataframe named as df
train_data = pd.read_csv("C:/Users/arora/OneDrive/Desktop/CIND 820/Literature Review/Dataset/Training.csv")
test_data = pd.read_csv("C:/Users/arora/OneDrive/Desktop/CIND 820/Literature Review/Dataset/Testing (1).csv")

# %%
#drop the column which has NaN values in the dataset (Unnamed: 133)
train_data.dropna(how="all",axis=1,inplace=True)

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# Separate the features (X) and target variable (y)
X = train_data.drop('prognosis', axis=1)  # Replace 'target_column' with the actual column name
y = train_data['prognosis']

# Create an instance of the Random Forest classifier
model = RandomForestClassifier()

# Train the Random Forest model
model.fit(X, y)

# Get feature importances
importances = model.feature_importances_

# Create a DataFrame with feature names and their importances
feature_importances =  pd.DataFrame({'Feature': X.columns, 'Importance': importances})

# Sort the features by importance in descending order
feature_importances = feature_importances.sort_values(by='Importance', ascending=False)

# Print the feature importances in a table format
print('Feature Importances:')
print(feature_importances.to_string())
# Out:
# Feature Importances:
#                             Feature  Importance
# 97                      muscle_pain    0.019984
# 6                        joint_pain    0.016964
# 0                           itching    0.015365
# 14                          fatigue    0.015247
# 106                  family_history    0.014632
# 34                           nausea    0.014417
# 11                         vomiting    0.014338
# 33                       dark_urine    0.014279
# 41                       mild_fever    0.013975
# 43                yellowing_of_eyes    0.013895
# 98                altered_sensorium    0.013168
# 28                         sweating    0.012995
# 25                       high_fever    0.012772
# 109           lack_of_concentration    0.012706
# 58                  fast_heart_rate    0.012268
# 40                        diarrhoea    0.011939
# 80                  muscle_weakness    0.011553
# 107                   mucoid_sputum    0.011535
# 56                       chest_pain    0.011385
# 89               bladder_discomfort    0.010978
# 27                   breathlessness    0.010960
# 31                         headache    0.010931
# 113                            coma    0.010888
# 85                  loss_of_balance    0.010885
# 108                    rusty_sputum    0.010852
# 93                 internal_itching    0.010755
# 48                          malaise    0.010663
# 131               yellow_crust_ooze    0.010464
# 35                 loss_of_appetite    0.010267
# 91         continuous_feel_of_urine    0.009771
# 24                            cough    0.009716
# 99              red_spots_over_body    0.009652
# 19                      weight_loss    0.009648
# 2              nodal_skin_eruptions    0.009517
# 5                            chills    0.009511
# 102             dischromic _patches    0.009433
# 86                     unsteadiness    0.009357
# 13              spotting_ urination    0.009233
# 22                patches_in_throat    0.009103
# 39                   abdominal_pain    0.009039
# 26                      sunken_eyes    0.008961
# 7                      stomach_pain    0.008797
# 36             pain_behind_the_eyes    0.008735
# 63                        neck_pain    0.008655
# 77                   slurred_speech    0.008466
# 32                   yellowish_skin    0.008314
# 114                stomach_bleeding    0.008312
# 92                 passage_of_gases    0.008156
# 96                     irritability    0.008041
# 3               continuous_sneezing    0.008029
# 87        weakness_of_one_body_side    0.008008
# 118                 blood_in_sputum    0.007939
# 82                  swelling_joints    0.007929
# 64                        dizziness    0.007913
# 111     receiving_blood_transfusion    0.007769
# 104              increased_appetite    0.007717
# 124                        scurring    0.007712
# 79                   hip_joint_pain    0.007688
# 122              pus_filled_pimples    0.007616
# 38                     constipation    0.007583
# 29                      dehydration    0.007546
# 101           abnormal_menstruation    0.007398
# 112  receiving_unsterile_injections    0.007365
# 105                        polyuria    0.007361
# 100                      belly_pain    0.007162
# 110             visual_disturbances    0.007158
# 103              watering_from_eyes    0.007113
# 46              swelling_of_stomach    0.007084
# 47              swelled_lymph_nodes    0.007079
# 129                         blister    0.006946
# 116  history_of_alcohol_consumption    0.006890
# 8                           acidity    0.006877
# 123                      blackheads    0.006853
# 57                weakness_in_limbs    0.006816
# 94              toxic_look_(typhos)    0.006748
# 9                  ulcers_on_tongue    0.006514
# 128              inflammatory_nails    0.006495
# 75           extra_marital_contacts    0.006483
# 1                         skin_rash    0.006377
# 59      pain_during_bowel_movements    0.006280
# 10                   muscle_wasting    0.006241
# 12              burning_micturition    0.006215
# 83               movement_stiffness    0.006136
# 68                     swollen_legs    0.006119
# 130            red_sore_around_nose    0.006114
# 127            small_dents_in_nails    0.006077
# 50                           phlegm    0.005909
# 72                    brittle_nails    0.005893
# 84               spinning_movements    0.005839
# 37                        back_pain    0.005751
# 61                     bloody_stool    0.005717
# 120                    palpitations    0.005696
# 119         prominent_veins_on_calf    0.005627
# 81                       stiff_neck    0.005533
# 125                    skin_peeling    0.005492
# 21                         lethargy    0.005443
# 126             silver_like_dusting    0.005359
# 78                        knee_pain    0.005283
# 117                fluid_overload.1    0.005209
# 4                         shivering    0.005134
# 71                 enlarged_thyroid    0.005109
# 74                 excessive_hunger    0.005096
# 65                           cramps    0.005002
# 121                 painful_walking    0.004968
# 115           distention_of_abdomen    0.004856
# 44              acute_liver_failure    0.004563
# 66                         bruising    0.004523
# 30                      indigestion    0.004349
# 95                       depression    0.004317
# 60              pain_in_anal_region    0.004241
# 20                     restlessness    0.004194
# 42                     yellow_urine    0.004130
# 73              swollen_extremeties    0.004065
# 88                    loss_of_smell    0.004031
# 62               irritation_in_anus    0.003884
# 53                   sinus_pressure    0.003829
# 54                       runny_nose    0.003804
# 55                       congestion    0.003642
# 51                throat_irritation    0.003584
# 76         drying_and_tingling_lips    0.003452
# 49     blurred_and_distorted_vision    0.003261
# 67                          obesity    0.003063
# 18                      mood_swings    0.002505
# 23            irregular_sugar_level    0.002340
# 52                  redness_of_eyes    0.002319
# 70              puffy_face_and_eyes    0.002317
# 90              foul_smell_of urine    0.001997
# 16                          anxiety    0.001841
# 15                      weight_gain    0.001472
# 17             cold_hands_and_feets    0.001446
# 69            swollen_blood_vessels    0.001089
# 45                   fluid_overload    0.000000

# %% [markdown]
# The feature "fluid_overload" has a feature importance of 0.0, which means that it is not a significant predictor of the
# disease. This is likely because fluid overload is a symptom of many different diseases, so it is not specific enough to
# be a reliable predictor
